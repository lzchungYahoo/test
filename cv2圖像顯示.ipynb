# %% [markdown]
# <a href="https://colab.research.google.com/github/lzchungYahoo/test/blob/main/cv2%E5%9C%96%E5%83%8F%E9%A1%AF%E7%A4%BA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 傳統 cv2 顯示影像

# %%
import cv2

img = cv2.imread(r"/content/drive/MyDrive/Colab Mycode/lena.jpg")
cv2.imshow("Image", img)  # google colab 無法使用
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-2-1cdc1415b26c> in <cell line: 0>()
#       2
#       3 img = cv2.imread(r"/content/drive/MyDrive/Colab Mycode/lena.jpg")
# ----> 4 cv2.imshow("Image", img)  # google colab 無法使用
#       5 cv2.waitKey(0)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      48   def wrapped(*args, **kwargs):
#      49     if not os.environ.get(env_var, False):
# ---> 50       raise DisabledFunctionError(message, name or func.__name__)
#      51     return func(*args, **kwargs)
#      52
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %% [markdown]
# 使用google內建cv2_imshow

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread(r"/content/drive/MyDrive/Colab Mycode/lena.jpg")
print(img.shape)
cv2_imshow(img)
# Out:
# (316, 316, 3)
# <PIL.Image.Image image mode=RGB size=316x316>

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread(r"https://github.com/lzchungYahoo/test/blob/ee7b9e3de970f4d2282e4aa805df6c9e47bddb37/lena.jpg")
print(img.shape)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-71a2de0c4644> in <cell line: 0>()
#       3
#       4 img = cv2.imread(r"https://github.com/lzchungYahoo/test/blob/ee7b9e3de970f4d2282e4aa805df6c9e47bddb37/lena.jpg")
# ----> 5 print(img.shape)
#       6 cv2_imshow(img)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread(r"/content/drive/MyDrive/Colab Mycode/lena.jpg")
print(img.shape)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-10fd556949d0> in <cell line: 0>()
#       3
#       4 img = cv2.imread(r"/content/drive/MyDrive/Colab Mycode/lena.jpg")
# ----> 5 print(img.shape)
#       6 cv2_imshow(img)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# 使用Matpoltlib.pyplot來顯示圖像

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread("/content/drive/MyDrive/code/lena.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
#透過IPython.display

import cv2
from IPython.display import display, clear_output

img1 = cv2.imread("/content/drive/MyDrive/code/lena.jpg")
img2 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

display(img2)
clear_output(wait=True)
# Out:
# array([[[225, 137, 125],
#         [224, 137, 130],
#         [225, 137, 125],
#         ...,
#         [233, 149, 125],
#         [229, 145, 121],
#         [211, 115, 101]],
#
#        [[225, 137, 125],
#         [224, 137, 130],
#         [225, 137, 125],
#         ...,
#         [233, 149, 125],
#         [229, 145, 121],
#         [211, 115, 101]],
#
#        [[225, 137, 125],
#         [225, 136, 130],
#         [225, 137, 127],
#         ...,
#         [233, 149, 125],
#         [228, 144, 118],
#         [211, 115, 101]],
#
#        ...,
#
#        [[ 92,  28,  63],
#         [ 90,  26,  61],
#         [ 92,  28,  65],
#         ...,
#         [157,  63,  79],
#         [167,  65,  78],
#         [164,  62,  76]],
#
#        [[ 83,  21,  60],
#         [ 89,  23,  59],
#         [ 94,  26,  65],
#         ...,
#         [168,  67,  81],
#         [174,  70,  79],
#         [177,  67,  80]],
#
#        [[ 82,  22,  58],
#         [ 90,  30,  58],
#         [ 95,  30,  64],
# ...

# %% [markdown]
# 使用Pillow來顯示圖案

# %%
from PIL import Image
import matplotlib.pyplot as plt

# 將 'image.jpg' 替換為您的彩色圖片檔案路徑
img = Image.open('/content/drive/MyDrive/code/lena.jpg')

plt.imshow(img)
plt.title('Color Image')
plt.axis('off')

plt.show()


# gray_img  = img.convert('L')
# for i in range(img.size[0]):
#     for j in range(img.size[1]):

#         gray_value = gray_img.getpixel((i, j))
#         if gray_value >128:
#             gray_img.putpixel((i, j), 255)
#         else:
#             gray_img.putpixel((i, j), 0)
